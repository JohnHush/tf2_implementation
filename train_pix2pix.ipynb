# %%
from model.pix2pix import train

# %%
train()
# Out:
# Epoch:  0
# .................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2da0ffaf5447> in <module>
# ----> 1 train()
#
# ~/working_pros/tf2_implementation/model/pix2pix.py in train()
#     103
#     104             generator_gradients = gen_tape.gradient(gen_total_loss,
# --> 105                                                     generator.trainable_variables)
#     106             discriminator_gradients = disc_tape.gradient(disc_loss,
#     107                                                          discriminator.trainable_variables)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1071         output_gradients=output_gradients,
#    1072         sources_raw=flat_sources_raw,
# ...
